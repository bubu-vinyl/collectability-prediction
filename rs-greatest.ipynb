# %%
import pandas as pd

df = pd.read_csv('datasets/rollingstones_500_greatest_albums.csv', encoding = "unicode_escape")

# %%
df
# Out:
#      Number  Year                                  Album             Artist  \
# 0         1  1967  Sgt. Pepper's Lonely Hearts Club Band        The Beatles
# 1         2  1966                             Pet Sounds     The Beach Boys
# 2         3  1966                               Revolver        The Beatles
# 3         4  1965                   Highway 61 Revisited          Bob Dylan
# 4         5  1965                            Rubber Soul        The Beatles
# ..      ...   ...                                    ...                ...
# 495     496  1969                             Boz Scaggs         Boz Scaggs
# 496     497  2001                      White Blood Cells  The White Stripes
# 497     498  1989                        The Stone Roses    The Stone Roses
# 498     499  1971               Live in Cook County Jail          B.B. King
# 499     500  1998                               Aquemini            OutKast
#
# ...

# %%
df_p4kxspotify = pd.read_csv('datasets/p4kXspotify.csv', encoding = "unicode_escape")
df_p4kxspotify
# Out:
#                artist                              album        reviewauthor  \
# 0            Studio 1                           Studio 1      Andy Battaglia
# 1          John Fahey  The Great Santa Barbara Oil Slick     Mark Richardson
# 2      Reigning Sound                    Too Much Guitar  Stephen M. Deusner
# 3      The Red Thread                     After the Last        Chris Dahlen
# 4          Mac Miller                           Swimming      Evan Rytlewski
# ...               ...                                ...                 ...
# 18398       DJ Khaled                    Father of Asahd       Rawiya Kameir
# 18399        Interpol                     A Fine Mess EP       Brian Josephs
# 18400  Injury Reserve                     Injury Reserve      Sheldon Pearce
# 18401       Operators                       Radiant Dawn       Stuart Berman
# 18402        Slowthai        Nothing Great About Britain         Jazz Monroe
#
# ...
